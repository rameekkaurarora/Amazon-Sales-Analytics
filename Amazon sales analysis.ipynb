# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Amazon Sales Data.csv')
df=pd.DataFrame(data=df)
df
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
df.head()
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority  Order Date   Order ID   Ship Date  Units Sold  \
# 0       Offline              H   5/28/2010  669165933   6/27/2010        9925
# 1        Online              C   8/22/2012  963881480   9/15/2012        2804
# 2       Offline              L  05-02-2014  341417157  05-08-2014        1779
# 3        Online              C   6/20/2014  514321792  07-05-2014        8102
# 4       Offline              L  02-01-2013  115456712  02-06-2013        5062
#
# ...

# %%
df.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
df.shape
# Out:
# (100, 14)

# %%
df.size
# Out:
# 1400

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          100 non-null    object
#  1   Country         100 non-null    object
#  2   Item Type       100 non-null    object
#  3   Sales Channel   100 non-null    object
#  4   Order Priority  100 non-null    object
#  5   Order Date      100 non-null    object
#  6   Order ID        100 non-null    int64
#  7   Ship Date       100 non-null    object
#  8   Units Sold      100 non-null    int64
#  9   Unit Price      100 non-null    float64
#  10  Unit Cost       100 non-null    float64
#  11  Total Revenue   100 non-null    float64
#  12  Total Cost      100 non-null    float64
#  13  Total Profit    100 non-null    float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 11.1+ KB

# %%
df.describe()
# Out:
#            Order ID   Units Sold  Unit Price   Unit Cost  Total Revenue  \
# count  1.000000e+02   100.000000  100.000000  100.000000   1.000000e+02
# mean   5.550204e+08  5128.710000  276.761300  191.048000   1.373488e+06
# std    2.606153e+08  2794.484562  235.592241  188.208181   1.460029e+06
# min    1.146066e+08   124.000000    9.330000    6.920000   4.870260e+03
# 25%    3.389225e+08  2836.250000   81.730000   35.840000   2.687212e+05
# 50%    5.577086e+08  5382.500000  179.880000  107.275000   7.523144e+05
# 75%    7.907551e+08  7369.000000  437.200000  263.330000   2.212045e+06
# max    9.940222e+08  9925.000000  668.270000  524.960000   5.997055e+06
#
#          Total Cost  Total Profit
# count  1.000000e+02  1.000000e+02
# mean   9.318057e+05  4.416820e+05
# std    1.083938e+06  4.385379e+05
# min    3.612240e+03  1.258020e+03
# 25%    1.688680e+05  1.214436e+05
# 50%    3.635664e+05  2.907680e+05
# 75%    1.613870e+06  6.358288e+05
# max    4.509794e+06  1.719922e+06

# %%
df.isna().sum()
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %%
df.dtypes
# Out:
# Region             object
# Country            object
# Item Type          object
# Sales Channel      object
# Order Priority     object
# Order Date         object
# Order ID            int64
# Ship Date          object
# Units Sold          int64
# Unit Price        float64
# Unit Cost         float64
# Total Revenue     float64
# Total Cost        float64
# Total Profit      float64
# dtype: object

# %%
df=df.astype({'Ship Date':'datetime64[ns]','Order Date':'datetime64[ns]'})

# %%
df.dtypes
# Out:
# Region                    object
# Country                   object
# Item Type                 object
# Sales Channel             object
# Order Priority            object
# Order Date        datetime64[ns]
# Order ID                   int64
# Ship Date         datetime64[ns]
# Units Sold                 int64
# Unit Price               float64
# Unit Cost                float64
# Total Revenue            float64
# Total Cost               float64
# Total Profit             float64
# dtype: object

# %% [markdown]
# #### Region with Highest total Sales revenue

# %%
Highest_revenue = df.groupby(df['Region'])['Total Revenue'].sum()
Highest_revenue.idxmax()
# Out:
# 'Sub-Saharan Africa'

# %%
group_data=df.groupby(df['Region'])['Total Revenue'].sum()
sns.set_style('darkgrid')
plt.figure(figsize=(15,5))
sns.lineplot(data=group_data,linestyle='--',linewidth=4,marker='o',markersize=10,markerfacecolor='red',markeredgecolor='black')

plt.xticks(rotation=90)
plt.title('Highest Total Sales Revenue by Region',fontsize=20,color='Blue')
plt.xlabel('Regions',fontsize=20,color='red')
plt.ylabel('Revenue',fontsize=20,color='c')
plt.show()

# %% [markdown]
# #### Average unit price and unit cost of each item

# %%
Unit_price_avg=df.groupby(df['Item Type'])['Unit Price'].mean()
Unit_cost_avg=df.groupby(df['Item Type'])['Unit Cost'].mean()

cost_price_avg=pd.DataFrame({'Average Unit Price':Unit_price_avg,
                              'Average Unit Cost':Unit_cost_avg})

cost_price_avg
# Out:
#                  Average Unit Price  Average Unit Cost
# Item Type
# Baby Food                    255.28             159.42
# Beverages                     47.45              31.79
# Cereal                       205.70             117.11
# Clothes                      109.28              35.84
# Cosmetics                    437.20             263.33
# Fruits                         9.33               6.92
# Household                    668.27             502.54
# Meat                         421.89             364.69
# Office Supplies              651.21             524.96
# Personal Care                 81.73              56.67
# Snacks                       152.58              97.44
# Vegetables                   154.06              90.93

# %% [markdown]
# #### Country with Highest profit

# %%
Total_profit_country=df.groupby(df['Country'])['Total Profit'].sum()
Highest_total_profit_country= Total_profit_country.idxmax()

print("Country with highest total profit is :",Highest_total_profit_country)
# Out:
# Country with highest total profit is : Djibouti

# %%
group_data=df.groupby(df['Country'])['Total Profit'].sum()
sns.set_style('darkgrid')
plt.figure(figsize=(15,5))
sns.barplot(x=group_data.index,y=group_data)

plt.xticks(rotation=90)
plt.title('Country with Highest Total Profit',fontsize=20,color='Blue')
plt.xlabel('Country',fontsize=20,color='red')
plt.ylabel('Profit',fontsize=20,color='c')
plt.show()

# %% [markdown]
# #### How sales channel affect the order priority distribution

# %%
Sales_channel_order_priority_distribution=df.groupby(df['Sales Channel'])['Order Priority'].value_counts()
Sales_channel_order_priority_distribution
# Out:
# Sales Channel  Order Priority
# Offline        H                 17
#                C                 13
#                L                 12
#                M                  8
# Online         L                 15
#                H                 13
#                M                 13
#                C                  9
# Name: count, dtype: int64

# %%
Sales_channel_order_priority_distribution=df.groupby(df['Sales Channel'])['Order Priority'].value_counts()
Sales_channel_order_priority_distribution=Sales_channel_order_priority_distribution.reset_index(name='Count')

sns.set_style('darkgrid')

plt.figure(figsize=(10,6))
sns.barplot(x='Sales Channel',y='Count',hue='Order Priority',data=Sales_channel_order_priority_distribution)

plt.xlabel('Sales Channel')
plt.ylabel('Count')
plt.title('Sales channel order priority distribution')
plt.show()

# %% [markdown]
# #### Average order processing time for each sales channel

# %%
df['Processing Time']=df['Ship Date']-df['Order Date']

avg_processing_time = df.groupby(df['Sales Channel'])['Processing Time'].mean()
avg_processing_time
# Out:
# Sales Channel
# Offline   23 days 04:48:00
# Online    23 days 12:28:48
# Name: Processing Time, dtype: timedelta64[ns]

# %%
plt.figure(figsize=(7,6))
sns.barplot(data=df,x=df['Sales Channel'],y=df['Processing Time'].dt.days , width=0.4)

plt.title('Average Processing Time by sales channel')
plt.xlabel('Sales Channel')
plt.yticks(np.arange(0,25,1))
plt.ylabel('Average Processing Time by sales channel')

plt.show()

# %% [markdown]
# #### Item type having highest and lowest sale

# %%
group_item_type=df.groupby(df['Item Type'])['Total Revenue'].sum()

highest_sales_item_type = group_item_type.idxmax()
lowest_sales_item_type = group_item_type.idxmin()
print("Highest sales revenue by item type:",highest_sales_item_type,"\n"'Lowest sales revenue by item type:',lowest_sales_item_type)
# Out:
# Highest sales revenue by item type: Cosmetics
# Lowest sales revenue by item type: Fruits

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x=group_item_type.index,y=group_item_type , s=200)
max_index=group_item_type.idxmax()
plt.scatter(x=max_index,y=group_item_type[max_index],s=200,color='Green',edgecolor='black')

min_index=group_item_type.idxmin()
plt.scatter(x=min_index,y=group_item_type[min_index],s=200,color='Red',edgecolor='black')

plt.xticks(rotation=45)
plt.yticks(rotation=0)

plt.show()

# %% [markdown]
# #### order priority across diffenet regions?

# %%
dif_regions_order_priority=df.groupby(df['Region'])['Order Priority'].value_counts()
dif_regions_order_priority
# Out:
# Region                             Order Priority
# Asia                               L                  4
#                                    H                  3
#                                    C                  2
#                                    M                  2
# Australia and Oceania              H                  5
#                                    C                  4
#                                    L                  1
#                                    M                  1
# Central America and the Caribbean  C                  2
#                                    H                  2
#                                    L                  2
#                                    M                  1
# Europe                             H                  7
#                                    L                  6
#                                    C                  5
#                                    M                  4
# ...

# %%
dif_regions_order_priority=df.groupby(df['Region'])['Order Priority'].value_counts().reset_index(name='Order Priority Count')
plt.figure(figsize=(10,5))
sns.barplot(data=dif_regions_order_priority,x='Region',y='Order Priority Count',hue='Order Priority')
plt.xticks(rotation=90)
plt.yticks(np.arange(1,12,1))
plt.show()

# %% [markdown]
# #### Corelation between unit price and total profit?

# %%
correlation_unit_price_total_profit=df['Unit Price'].corr(df['Total Profit'])
print('Correlation between unit price and total profit',correlation_unit_price_total_profit)
# Out:
# Correlation between unit price and total profit 0.5573652488121267

# %%
plt.figure(figsize=(4,2))
plt.scatter(x=correlation_unit_price_total_profit , y=correlation_unit_price_total_profit,s=200,color='Red')
plt.xticks(np.arange(-1,2,0.5))
plt.yticks(np.arange(-1,2,0.5))
plt.title('Correlation Unit Price Total Profit')
plt.show()

# %% [markdown]
# #### Seasonal trends or patterns in sales data

# %%
month_names= {1: 'Jan',
              2: ' Feb',
              3: 'Mar',
              4 :'Apr',
              5:'May',
              6:'Jun',
              7:'Jul',
              8:'Aug',
              9:'Sep',
              10:'Oct',
              11:'Nov',
              12:'Dec'}

monthly_sales=df.groupby(df['Order Date'].dt.month)['Total Revenue'].sum()
monthly_sales.index=monthly_sales.index.map(month_names)
monthly_sales
# Out:
# Order Date
# Jan     10482467.12
#  Feb    24740517.77
# Mar      2274823.87
# Apr     16187186.33
# May     13215739.99
# Jun      5230325.77
# Jul     15669518.50
# Aug      1128164.91
# Sep      5314762.56
# Oct     15287576.61
# Nov     20568222.76
# Dec      7249462.12
# Name: Total Revenue, dtype: float64

# %%
sns.barplot(x=monthly_sales.index , y=monthly_sales)
plt.title('Month wise total Revenue')
plt.xlabel('Month')
plt.ylabel('Total Revenue')
plt.show()

# %% [markdown]
# #### Unit sold across different countries

# %%
diff_countries_by_unit=df.groupby(df['Country'])['Units Sold'].sum().reset_index(name='Unit Sold')
pd.set_option('display.max_rows',None)
diff_countries_by_unit
# Out:
#                              Country  Unit Sold
# 0                            Albania       2269
# 1                             Angola       4187
# 2                          Australia      12995
# 3                            Austria       2847
# 4                         Azerbaijan       9255
# 5                         Bangladesh       8263
# 6                             Belize       5498
# 7                             Brunei       6708
# 8                           Bulgaria       5660
# 9                       Burkina Faso       8082
# 10                          Cameroon      10948
# 11                        Cape Verde       4168
# 12                           Comoros        962
# 13                        Costa Rica       6409
# 14                     Cote d'Ivoire       3482
# 15  Democratic Republic of the Congo       5741
# 16                          Djibouti      23198
# 17                        East Timor       5908
# 18    Federated States of Micronesia       9379
# ...

# %%
plt.figure(figsize=(18,7))
sns.barplot(data=diff_countries_by_unit,x='Country',y='Unit Sold')
plt.xticks(rotation=90)
plt.yticks(np.arange(0,26000,1000))
plt.show()

# %% [markdown]
# #### Sales revenue across different countries

# %%
sales_revenue_by_countries=df.groupby(['Country'])['Total Revenue'].sum().reset_index(name='Total Revenue')
sales_revenue_by_countries
# Out:
#                              Country  Total Revenue
# 0                            Albania      247956.32
# 1                             Angola     2798046.49
# 2                          Australia     2489933.49
# 3                            Austria     1244708.40
# 4                         Azerbaijan     4478800.21
# 5                         Bangladesh      902980.64
# 6                             Belize      600821.44
# 7                             Brunei     4368316.68
# 8                           Bulgaria     2779199.71
# 9                       Burkina Faso     1245112.92
# 10                          Cameroon     3851030.28
# 11                        Cape Verde      455479.04
# 12                           Comoros      197883.40
# 13                        Costa Rica      523807.57
# 14                     Cote d'Ivoire      380512.96
# 15  Democratic Republic of the Congo      272410.45
# 16                          Djibouti     6052890.86
# ...

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=sales_revenue_by_countries['Country'],y=sales_revenue_by_countries['Total Revenue'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Distribution of unit price of each item type

# %%
unit_price_and_item_type_distribution=df.groupby(df['Item Type'])['Unit Price'].sum().reset_index(name='Unit Price')
unit_price_and_item_type_distribution
# Out:
#           Item Type  Unit Price
# 0         Baby Food     1786.96
# 1         Beverages      379.60
# 2            Cereal     1439.90
# 3           Clothes     1420.64
# 4         Cosmetics     5683.60
# 5            Fruits       93.30
# 6         Household     6014.43
# 7              Meat      843.78
# 8   Office Supplies     7814.52
# 9     Personal Care      817.30
# 10           Snacks      457.74
# 11       Vegetables      924.36

# %%
plt.pie(x=unit_price_and_item_type_distribution['Unit Price'],labels=unit_price_and_item_type_distribution['Item Type'],autopct='%1.1f%%')
plt.axis('equal')
plt.show()

# %% [markdown]
# #### Sales channel with highest average unit price

# %%
highest_avg_unit_prie_for_sales_channel=df.groupby(df['Sales Channel'])['Unit Price'].mean().reset_index(name='new')
highest_avg_unit_prie_for_sales_channel
# Out:
#   Sales Channel       new
# 0       Offline  310.7206
# 1        Online  242.8020

# %%
plt.pie(x=highest_avg_unit_prie_for_sales_channel['new'],labels=highest_avg_unit_prie_for_sales_channel['Sales Channel'],autopct='%1.1f%%')
plt.axis('equal')
plt.show()

# %% [markdown]
# #### Outliers in total cost distribution

# %%
q1=df['Total Cost'].quantile(0.25)
q3=df['Total Cost'].quantile(0.75)

iqr=q3-q1
lower_fence=q1-1.5*iqr
upper_fence=q3+1.5*iqr

outliers=df[(df['Total Cost']<lower_fence) | (df['Total Cost']>upper_fence)].reset_index(drop=True)
outliers
# Out:
#                               Region    Country        Item Type  \
# 0  Central America and the Caribbean   Honduras        Household
# 1                               Asia    Myanmar        Household
# 2                             Europe  Lithuania  Office Supplies
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 0       Offline              H 2017-02-08  522840487 2017-02-13        8974
# 1       Offline              H 2015-01-16  177713572 2015-03-01        8250
# 2       Offline              H 2010-10-24  166460740 2010-11-17        8287
#
#    Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit  \
# 0      668.27     502.54     5997054.98  4509793.96    1487261.02
# 1      668.27     502.54     5513227.50  4145955.00    1367272.50
# 2      651.21     524.96     5396577.27  4350343.52    1046233.75
#
#   Processing Time
# 0          5 days
# 1         44 days
# 2         24 days

# %%
plt.boxplot(df['Total Cost'])
plt.title('Boxplot of Total Cost')
plt.show()

# %% [markdown]
# #### Total profit across different item types

# %%
total_profit_and_diff_item_types=df.groupby(df['Item Type'])['Total Profit'].sum().reset_index(name='Total Profit')
total_profit_and_diff_item_types
# Out:
#           Item Type  Total Profit
# 0         Baby Food    3886643.70
# 1         Beverages     888047.28
# 2            Cereal    2292443.43
# 3           Clothes    5233334.40
# 4         Cosmetics   14556048.66
# 5            Fruits     120495.18
# 6         Household    7412605.71
# 7              Meat     610610.00
# 8   Office Supplies    5929583.75
# 9     Personal Care    1220622.48
# 10           Snacks     751944.18
# 11       Vegetables    1265819.63

# %% [markdown]
# #### Average order processing time country wise

# %%
avg_processing_time_by_country=df.groupby(df['Country'])['Processing Time'].mean()
avg_processing_time_by_country
# Out:
# Country
# Albania                            44 days 00:00:00
# Angola                              4 days 00:00:00
# Australia                          18 days 16:00:00
# Austria                             7 days 00:00:00
# Azerbaijan                         30 days 00:00:00
# Bangladesh                         47 days 00:00:00
# Belize                             44 days 00:00:00
# Brunei                             37 days 00:00:00
# Bulgaria                           26 days 12:00:00
# Burkina Faso                       10 days 00:00:00
# Cameroon                           12 days 12:00:00
# Cape Verde                         17 days 00:00:00
# Comoros                            31 days 00:00:00
# Costa Rica                         13 days 00:00:00
# Cote d'Ivoire                      19 days 00:00:00
# Democratic Republic of the Congo   50 days 00:00:00
# Djibouti                           13 days 08:00:00
# East Timor                         42 days 00:00:00
# ...

# %% [markdown]
# #### Region with highest average total revenue per order

# %%
df['avg total revenue']=df['Total Revenue']/df['Units Sold']
highest_avg_total_revenue_per_order=df.groupby(df['Region'])['avg total revenue'].mean()
highest_avg_total_revenue_per_order.sort_values(ascending=True)
highest_avg_total_revenue_per_order.head(1)
# Out:
# Region
# Asia    335.809091
# Name: avg total revenue, dtype: float64

# %% [markdown]
# #### Relationship between numbers of unit sold and the total profit

# %%
correlation_unit_sold_and_total_profit=df['Units Sold'].corr(df['Total Profit'])
print(f"Correlation coefficient :{correlation_unit_sold_and_total_profit}")
# Out:
# Correlation coefficient :0.5645504620845976

# %% [markdown]
# #### Order priority based on item type

# %%
order_priority_vary_on_item_type=df.groupby(df['Order Priority'])['Item Type'].value_counts().reset_index(name='No. of Items')
order_priority_vary_on_item_type
# Out:
#    Order Priority        Item Type  No. of Items
# 0               C        Beverages             7
# 1               C          Clothes             4
# 2               C  Office Supplies             2
# 3               C    Personal Care             2
# 4               C       Vegetables             2
# 5               C        Baby Food             1
# 6               C           Cereal             1
# 7               C        Cosmetics             1
# 8               C           Fruits             1
# 9               C        Household             1
# 10              H        Cosmetics             8
# 11              H           Cereal             5
# 12              H        Baby Food             3
# 13              H          Clothes             3
# 14              H       Vegetables             3
# 15              H           Fruits             2
# 16              H        Household             2
# 17              H  Office Supplies             2
# ...
